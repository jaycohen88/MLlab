# %%
import csv
import pandas as pd
import numpy as np
import sklearn
import matplotlib

# %%
orders = pd.read_csv(r'/Users/jaycohen/Documents/NYCDSA/Homework/Machine_Learning_Lab/MLlab/Jay/data/Orders.csv')

# %%
## Problem 1

orders.loc[:,'Profit'] = orders.loc[:,'Profit'].str.replace(',','')
orders.loc[:,'Profit'] = orders.loc[:,'Profit'].str.replace('$','')
orders.loc[:,'Sales'] = orders.loc[:,'Sales'].str.replace(',','')
orders.loc[:,'Sales'] = orders.loc[:,'Sales'].str.replace('$','')

# %%
orders.loc[:,'Profit'] = pd.to_numeric(orders.loc[:,'Profit'])
orders.loc[:,'Sales'] = pd.to_numeric(orders.loc[:,'Sales'])

# %%
orders
# Out:
#        Row.ID                  Order.ID Order.Date Ship.Date       Ship.Mode  \
# 0       40098  CA-2014-AB10015140-41954   11/11/14  11/13/14     First Class
# 1       26341    IN-2014-JR162107-41675     2/5/14    2/7/14    Second Class
# 2       25330    IN-2014-CR127307-41929   10/17/14  10/18/14     First Class
# 3       13524   ES-2014-KM1637548-41667    1/28/14   1/30/14     First Class
# 4       47221   SG-2014-RH9495111-41948    11/5/14   11/6/14        Same Day
# ...       ...                       ...        ...       ...             ...
# 51285   29002   IN-2015-KE1642066-42174    6/19/15   6/19/15        Same Day
# 51286   34337  US-2014-ZD21925140-41765     5/6/14   5/10/14  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147    8/26/12   8/31/12    Second Class
# 51288    9596   MX-2013-RB1979518-41322    2/17/13   2/21/13  Standard Class
# 51289    6147   MX-2013-MC1810093-41416    5/22/13   5/26/13    Second Class
#
# ...

# %%
## Problem 2

orders['Order.Date'] = pd.to_datetime(orders['Order.Date'])
orders['Ship.Date'] = pd.to_datetime(orders['Ship.Date'])

# %%
orders
# Out:
#        Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
def season_of_date(date):
    year = str(date.year)
    seasons = {'spring': pd.date_range(start=year+'-03-21', end=year+'-06-20'),
               'summer': pd.date_range(start=year+'-06-21', end=year+'-09-22'),
               'autumn': pd.date_range(start=year+'-09-23', end=year+'-12-20')}
    if date in seasons['spring']:
        return 'spring'
    if date in seasons['summer']:
        return 'summer'
    if date in seasons['autumn']:
        return 'autumn'
    else:
        return 'winter'

# %%
orders['Season'] = orders['Order.Date'].map(season_of_date)

# %%
orders
# Out:
#        Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
season_inventory = orders.groupby(['Season','Category'], as_index=False)['Quantity'].sum()

# %%
season_inventory
# Out:
#     Season         Category  Quantity
# 0   autumn        Furniture     11907
# 1   autumn  Office Supplies     35364
# 2   autumn       Technology     11592
# 3   spring        Furniture      7490
# 4   spring  Office Supplies     24222
# 5   spring       Technology      7683
# 6   summer        Furniture      9412
# 7   summer  Office Supplies     30268
# 8   summer       Technology      9716
# 9   winter        Furniture      6083
# 10  winter  Office Supplies     18390
# 11  winter       Technology      6185

# %%
## Problem 3

returns = pd.read_csv(r'/Users/jaycohen/Documents/NYCDSA/Homework/Machine_Learning_Lab/MLlab/Jay/data/Returns.csv')

# %%
returns = returns.rename(columns={"Order ID":"Order.ID"})

# %%
returns
# Out:
#      Returned                  Order.ID           Region
# 0         Yes  CA-2012-SA20830140-41210       Central US
# 1         Yes  IN-2012-PB19210127-41259     Eastern Asia
# 2         Yes  CA-2012-SC20095140-41174       Central US
# 3         Yes    IN-2015-JH158207-42140          Oceania
# 4         Yes    IN-2014-LC168857-41747          Oceania
# ...       ...                       ...              ...
# 1074      Yes   IN-2014-DA1345058-41769    Southern Asia
# 1075      Yes  US-2013-HG14845140-41530       Eastern US
# 1076      Yes   US-2013-SJ2021582-41543  Central America
# 1077      Yes  CA-2015-EB13870140-42269       Eastern US
# 1078      Yes    EG-2014-PM894038-41846     North Africa
#
# [1079 rows x 3 columns]

# %%
returns_full = pd.merge(orders,returns,on='Order.ID',how='inner')

# %%
returns_full
# Out:
#       Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 0      30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 1      30190  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 2      30187  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 3      30193  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 4      30189  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# ...      ...                       ...        ...        ...             ...
# 2215   35040  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2216   35038  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2217      25   US-2013-SJ2021582-41543 2013-09-26 2013-09-29     First Class
# 2218   36974  CA-2012-ZC21910140-41271 2012-12-28 2013-01-04  Standard Class
# 2219   41315    EG-2014-PM894038-41846 2014-07-26 2014-07-30  Standard Class
#
# ...

# %%
def year_of_date(date):
    return str(date.year)

# %%
returns_full['Year'] = returns_full['Order.Date'].map(year_of_date)

# %%
returns_full
# Out:
#       Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 0      30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 1      30190  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 2      30187  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 3      30193  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 4      30189  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# ...      ...                       ...        ...        ...             ...
# 2215   35040  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2216   35038  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2217      25   US-2013-SJ2021582-41543 2013-09-26 2013-09-29     First Class
# 2218   36974  CA-2012-ZC21910140-41271 2012-12-28 2013-01-04  Standard Class
# 2219   41315    EG-2014-PM894038-41846 2014-07-26 2014-07-30  Standard Class
#
# ...

# %%
returns_full['Year'] = pd.to_numeric(returns_full['Year'])

# %%
yearly_lost_profits = returns_full.groupby(['Year'], as_index=False)['Profit'].sum()

# %%
yearly_lost_profits
# Out:
#    Year    Profit
# 0  2012  17477.26
# 1  2013   9269.89
# 2  2014  17510.63
# 3  2015  17112.97
